# %% [markdown]
# ### <span style=color:blue> Loading Calendar data from csv into local MongoDB    </span>

# %%
import sys
import json
import csv
import yaml

import importlib

import pandas as pd
import numpy as np

import matplotlib as mpl
import matplotlib.pyplot as plt
import os
from dotenv import load_dotenv

from datetime import time
from datetime import date
from datetime import datetime
# with the above choices, the imported datetime.time(2023,07,01) is recognized
# from datetime import date
# from datetime import datetime

import pprint

import psycopg2
from sqlalchemy import create_engine, text as sql_text

# Create an utilities file util.py in a folder benchmarking and import it
sys.path.append('helper_functions/')
# import util as util
import util

# %% [markdown]
# <span style=color:blue>Getting mongodb connection set up</span>

# %%
from pymongo import MongoClient

client = MongoClient()
# could have written client = MongoClient("localhost", 27017)
#                 or client = MongoClient("mongodb://localhost:27017/")

# %% [markdown]
# <span style=color:blue>Getting access to airbnb database, and setting up collection "cal" to hold the calendar data in mongodb</span>

# %%
# I have (or will have) a database "airbnb"
db = client.airbnb


print('The list of all databases currently in the MongoDB client is:')
print(client.list_database_names())

print('\nThe list of all collections in the airbnb database is:')
print(db.list_collection_names())
# Note: calendar may not show up yet; it is created only when a first document is inserted into it
# Out:
# The list of all databases currently in the MongoDB client is:
# ['admin', 'airbnb', 'company', 'config', 'local', 'test']
#
# The list of all collections in the airbnb database is:
# ['listings_test', 'reviews', 'reviews_t', 'calendar', 'listings_with_reviews_and_cal', 'listings_with_reviews_m', 'listings_with_calendar', 'listings_t', 'listings']

# %% [markdown]
# <span style=color:blue>Loading contents of calendar csv file into a dataframe</span>
#
# <span style=color:blue>The system will give a warning, but it appears safe to ignore it.</span>

# %%
filename = '/Users/benedictnursalim/Downloads/AirBnB--new_york_city/calendar.csv'

# Using partial list of dtypes, so that first several fields are interpreted as strings
# As for the date and available fields (intended as date type and boolean, respectively,
#    we import as strings and convert in the data frame
dtype = {"listing_id": str, "date": str, "available": str, 
        "price": str, "adjusted_price": str}
# note including these, because the null values make trouble:  , "minimum_nights": int, "maximum_nights": int}

# the csv has nulls in "adjusted_price", which has type str,. so including keep_default_na=False, 
#    see https://stackoverflow.com/questions/10867028/get-pandas-read-csv-to-read-empty-values-as-empty-string-instead-of-nan
         
df = pd.read_csv(filename, dtype=dtype, keep_default_na=False)
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[55], line 13
#       6 dtype = {"listing_id": str, "date": str, "available": str,
#       7         "price": str, "adjusted_price": str}
#       8 # note including these, because the null values make trouble:  , "minimum_nights": int, "maximum_nights": int}
#       9
#      10 # the csv has nulls in "adjusted_price", which has type str,. so including keep_default_na=False,
#      11 #    see https://stackoverflow.com/questions/10867028/get-pandas-read-csv-to-read-empty-values-as-empty-string-instead-of-nan
# ---> 13 df = pd.read_csv(filename, dtype=dtype, keep_default_na=False)
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/io/parsers/readers.py:948, in read_csv(filepath_or_buffer, sep, delimiter, header, names, index_col, usecols, dtype, engine, converters, true_values, false_values, skipinitialspace, skiprows, skipfooter, nrows, na_values, keep_default_na, na_filter, verbose, skip_blank_lines, parse_dates, infer_datetime_format, keep_date_col, date_parser, date_format, dayfirst, cache_dates, iterator, chunksize, compression, thousands, decimal, lineterminator, quotechar, quoting, doublequote, escapechar, comment, encoding, encoding_errors, dialect, on_bad_lines, delim_whitespace, low_memory, memory_map, float_precision, storage_options, dtype_backend)
#     935 kwds_defaults = _refine_defaults_read(
#     936     dialect,
#     937     delimiter,
#    (...)
#     944     dtype_backend=dtype_backend,
#     945 )
#     946 kwds.update(kwds_defaults)
# --> 948 return _read(filepath_or_buffer, kwds)
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/io/parsers/readers.py:617, in _read(filepath_or_buffer, kwds)
#     614     return parser
#     616 with parser:
# --> 617     return parser.read(nrows)
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/io/parsers/readers.py:1748, in TextFileReader.read(self, nrows)
#    1741 nrows = validate_integer("nrows", nrows)
#    1742 try:
#    1743     # error: "ParserBase" has no attribute "read"
#    1744     (
#    1745         index,
#    1746         columns,
#    1747         col_dict,
# -> 1748     ) = self._engine.read(  # type: ignore[attr-defined]
#    1749         nrows
#    1750     )
#    1751 except Exception:
#    1752     self.close()
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/io/parsers/c_parser_wrapper.py:236, in CParserWrapper.read(self, nrows)
#     234     chunks = self._reader.read_low_memory(nrows)
#     235     # destructive to chunks
# --> 236     data = _concatenate_chunks(chunks)
#     238 else:
#     239     data = self._reader.read(nrows)
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/io/parsers/c_parser_wrapper.py:376, in _concatenate_chunks(chunks)
#     374     result[name] = union_categoricals(arrs, sort_categories=False)
#     375 else:
# --> 376     result[name] = concat_compat(arrs)
#     377     if len(non_cat_dtypes) > 1 and result[name].dtype == np.dtype(object):
#     378         warning_columns.append(str(name))
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/dtypes/concat.py:126, in concat_compat(to_concat, axis, ea_compat_axis)
#     115         warnings.warn(
#     116             "The behavior of array concatenation with empty entries is "
#     117             "deprecated. In a future version, this will no longer exclude "
#    (...)
#     122             stacklevel=find_stack_level(),
#     123         )
#     125 if target_dtype is not None:
# --> 126     to_concat = [astype_array(arr, target_dtype, copy=False) for arr in to_concat]
#     128 if not isinstance(to_concat[0], np.ndarray):
#     129     # i.e. isinstance(to_concat[0], ExtensionArray)
#     130     to_concat_eas = cast("Sequence[ExtensionArray]", to_concat)
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/dtypes/concat.py:126, in <listcomp>(.0)
#     115         warnings.warn(
#     116             "The behavior of array concatenation with empty entries is "
#     117             "deprecated. In a future version, this will no longer exclude "
#    (...)
#     122             stacklevel=find_stack_level(),
#     123         )
#     125 if target_dtype is not None:
# --> 126     to_concat = [astype_array(arr, target_dtype, copy=False) for arr in to_concat]
#     128 if not isinstance(to_concat[0], np.ndarray):
#     129     # i.e. isinstance(to_concat[0], ExtensionArray)
#     130     to_concat_eas = cast("Sequence[ExtensionArray]", to_concat)
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:183, in astype_array(values, dtype, copy)
#     180     values = values.astype(dtype, copy=copy)
#     182 else:
# --> 183     values = _astype_nansafe(values, dtype, copy=copy)
#     185 # in pandas we don't store numpy str dtypes, so convert to object
#     186 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File ~/anaconda3/envs/streamlit/lib/python3.11/site-packages/pandas/core/dtypes/astype.py:134, in _astype_nansafe(arr, dtype, copy, skipna)
#     130     raise ValueError(msg)
#     132 if copy or arr.dtype == object or dtype == object:
#     133     # Explicit copy, or required since NumPy can't view from / to object.
# --> 134     return arr.astype(dtype, copy=True)
#     136 return arr.astype(dtype, copy=copy)
#
# KeyboardInterrupt:

# %%
print('The datatypes for the fields of df are:')
print(df.dtypes)

print('\nThe first few rows of df are:')
print(df.head())
# Out:
# The datatypes for the fields of df are:
# listing_id        object
# date              object
# available         object
# price             object
# adjusted_price    object
# minimum_nights    object
# maximum_nights    object
# dtype: object
#
# The first few rows of df are:
#   listing_id        date available    price adjusted_price minimum_nights  \
# 0     144087  2024-02-10         t  $259.00                            30
# 1     144087  2024-02-11         t  $259.00                            30
# 2     144087  2024-02-12         t  $259.00                            30
# 3     144087  2024-02-13         t  $259.00                            30
# 4     144087  2024-02-14         t  $259.00                            30
#
#   maximum_nights
# 0            365
# 1            365
# 2            365
# 3            365
# 4            365

# %% [markdown]
# <span style=color:blue>Function to convert dates into datetimes.  This is useful because MongoDB recognizes datetime types but not date types.  So, will convert all dates into datetimes for insertion into MongoDB (after which we can do date arithmetic).  It also has conditions that turn various kinds of null values into None.  (Note: curiously this works on small dataframes, but left some values of "NaT" when applied on very large dataframes.)</span>
#
# <span style=color:blue>This function had been developed when working with the listings join reviews data, where there were some NULL values.  There are no NULL values in the calendar data.</span>
#
# <span style=color:blue>A better sw engineering practice might be to include this function into the util.py file, but leaving it here to make the notebook more self-contained.</span>

# %%
# also converts NaT to None, because MongoDB does not recognize NaT
def convert_date_str_to_datetime(dt):
    if dt is None:
        return None
    elif pd.isnull(dt):  # tests whether dt is the pandas value NaT ("not a time")
        # print('\nEntered the NaT case\n')
        return None
    elif dt != dt:
        return None        # could also use math.nan, I think
    elif dt == '':
        return None
    else:
        year = int(dt[0:4])
        month = int(dt[5:7])
        day = int(dt[8:10])
        # print(year, month, day)
        temp = datetime(year, month, day)
        ts = temp.timestamp()
        new_dt = datetime.fromtimestamp(ts)
        return new_dt

print(convert_date_str_to_datetime('2024-05-23'))
# Out:
# 2024-05-23 00:00:00

# %% [markdown]
# <span style=color:blue>Function to convert the values of field "available" to booleans </span>

# %%
def convert_tf_to_boolean(val):
    if val == 't':
        return True
    elif val == 'f':
        return False
    else:
        return None

print(convert_tf_to_boolean('t'), convert_tf_to_boolean('f'), convert_tf_to_boolean('foo'))
# Out:
# True False None

# %% [markdown]
# <span style=color:blue>Cleaning up the values in df, to be more compatible with MongoDB  </span>

# %%
df['date'] = df['date'].apply(convert_date_str_to_datetime)
df['available'] = df['available'].apply(convert_tf_to_boolean)

print(df.head())
# Out:
#   listing_id       date  available    price adjusted_price minimum_nights  \
# 0     144087 2024-02-10       True  $259.00                            30
# 1     144087 2024-02-11       True  $259.00                            30
# 2     144087 2024-02-12       True  $259.00                            30
# 3     144087 2024-02-13       True  $259.00                            30
# 4     144087 2024-02-14       True  $259.00                            30
#
#   maximum_nights
# 0            365
# 1            365
# 2            365
# 3            365
# 4            365

# %% [markdown]
# <span style=color:blue>Cleaning and changing data type of price column.  (Not bothering with adjusted_price column, which appears to be uniformly NULL.   </span>

# %%
# need to strip the leading '$' from the price value, and remove commas
df['price'] = df['price'].apply(lambda x:x.replace('$','').replace(',',''))

# converting price which is string to numeric
df['price'] = pd.to_numeric(df['price']) 

print(type(df.loc[0,'price']))
print(df.head())
# Out:
# <class 'numpy.float64'>
#   listing_id       date  available  price adjusted_price minimum_nights  \
# 0     144087 2024-02-10       True  259.0                            30
# 1     144087 2024-02-11       True  259.0                            30
# 2     144087 2024-02-12       True  259.0                            30
# 3     144087 2024-02-13       True  259.0                            30
# 4     144087 2024-02-14       True  259.0                            30
#
#   maximum_nights
# 0            365
# 1            365
# 2            365
# 3            365
# 4            365

# %% [markdown]
# ### <span style=color:blue>Now working to fill listings_with_cal with the dataframe df.  After that we will use an agg function to produce a collection is an array of listings and for each listing an arracy of dates that it is available,   </span>
#
# <span style=color:blue>In this notebook we work directly with the full calendar data set.  You might want to work with a subset of the data, e.g., by using df_small = df.iloc[0:5000].</span>

# %% [markdown]
# <span style=color:blue>First step is to load the df into a dict</span>

# %%
time1 = datetime.now()
dict_full = df.to_dict('records')
time2 = datetime.now()
print(f'Time to perform this operation was {util.time_diff(time1,time2)} seconds.')
# Out:
# Time to perform this operation was 95.954139 seconds.

# %% [markdown]
# <span style=color:blue>Now loading the dictionary into MongoDB</span>

# %%
# The following empties out listings_with_cal; useful if making a fresh start
db.calendar.drop()

print(len(dict_full))

time1 = datetime.now()
result = db.calendar.insert_many(dict_full)
time2 = datetime.now()
print(f'\nTime to perform this operation was {util.time_diff(time1,time2)} seconds.')
# between about 2 and 4 minutes

print(f'\nNumber of docs in db.calendar is {db.calendar.count_documents({})}')

print()
outdocs = []
for o in result.inserted_ids[-5:]:
    outdocs.append(db.calendar.find_one({ '_id': o}))
pprint.pp(outdocs)
# Out:
# 14299870
#
# Time to perform this operation was 385.835024 seconds.
#
# Number of docs in db.calendar is 14299870
#
# [{'_id': ObjectId('665f95d77f7b19aa06105aa7'),
#   'listing_id': '1081185973600372871',
#   'date': datetime.datetime(2025, 1, 31, 0, 0),
#   'available': False,
#   'price': 160.0,
#   'adjusted_price': '',
#   'minimum_nights': 30,
#   'maximum_nights': 365},
#  {'_id': ObjectId('665f95d77f7b19aa06105aa8'),
#   'listing_id': '1081185973600372871',
#   'date': datetime.datetime(2025, 2, 1, 0, 0),
#   'available': False,
#   'price': 160.0,
#   'adjusted_price': '',
#   'minimum_nights': 30,
#   'maximum_nights': 365},
#  {'_id': ObjectId('665f95d77f7b19aa06105aa9'),
#   'listing_id': '1081185973600372871',
#   'date': datetime.datetime(2025, 2, 2, 0, 0),
#   'available': False,
#   'price': 160.0,
#   'adjusted_price': '',
#   'minimum_nights': 30,
#   'maximum_nights': 365},
#  {'_id': ObjectId('665f95d77f7b19aa06105aaa'),
#   'listing_id': '1081185973600372871',
#   'date': datetime.datetime(2025, 2, 3, 0, 0),
#   'available': False,
#   'price': 160.0,
#   'adjusted_price': '',
#   'minimum_nights': 30,
#   'maximum_nights': 365},
#  {'_id': ObjectId('665f95d77f7b19aa06105aab'),
#   'listing_id': '1081185973600372871',
#   'date': datetime.datetime(2025, 2, 4, 0, 0),
#   'available': False,
#   'price': 160.0,
#   'adjusted_price': '',
#   'minimum_nights': 30,
#   'maximum_nights': 365}]

# %%
print(len(dict_full))
print(db.calendar.count_documents({}))
# Out:
# 14299870
# 14299870

# %%
# Ensure the target collection is empty
db.listings_with_calendar.drop()

pipeline = [
    {
        "$group": {
            "_id": "$listing_id",
            "average_price": {"$avg": "$price"},  # Calculate average price
            "first_available_date": {"$min": "$date"},  # Find the earliest date
            "last_available_date": {"$max": "$date"},  # Find the latest date
            "dates_list": {
                "$push": {  # Collect detailed date information into a list
                    "date": "$date",
                    "price": "$price",
                    "minimum_nights": "$minimum_nights",
                    "maximum_nights": "$maximum_nights",
                    "available": "$available"

                }
            }
        }
    },
    {
        "$out": "listings_with_calendar"
    }
]

time1 = datetime.now()
test1 = db.calendar.aggregate(pipeline)  # Ensure 'calendar' is the correct collection to aggregate from
time2 = datetime.now()
diff = (time2 - time1).total_seconds()

print('\nTime it took was:', format(diff, '.4f'), '.')

print(db.list_collection_names())

print("test1:")
print(type(test1))


"""
Time it took was: 83.8091 .
['calendar', 'listings_with_calendar', 'testing', 'listings_previously_built', 'listings_with_reviews', 'listings_with_reviews_and_cal', 'calendar_previously_built', 'listings']
test1:
<class 'pymongo.command_cursor.CommandCursor'>
"""
# Out:
# Time it took was: 40.0937 .
# ['listings_test', 'calendar', 'listings', 'listings_with_calendar']
# test1:
# <class 'pymongo.command_cursor.CommandCursor'>
# "\nTime it took was: 83.8091 .\n['calendar', 'listings_with_calendar', 'testing', 'listings_previously_built', 'listings_with_reviews', 'listings_with_reviews_and_cal', 'calendar_previously_built', 'listings']\ntest1:\n<class 'pymongo.command_cursor.CommandCursor'>\n"

# %%
count = db.listings_with_calendar.count_documents({})
print(count)
# Out:
# 39201

# %%
pprint.pp(db.listings_with_calendar.find_one())
# Out:
# {'_id': '10000070',
#  'average_price': 85.0,
#  'first_available_date': datetime.datetime(2024, 2, 6, 0, 0),
#  'last_available_date': datetime.datetime(2025, 2, 4, 0, 0),
#  'dates_list': [{'date': datetime.datetime(2024, 2, 6, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 7, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 8, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 9, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 10, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 11, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 12, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 13, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 14, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 15, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 16, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 17, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 18, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 19, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 20, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 21, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 22, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 23, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 24, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 25, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 26, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 27, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 28, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 29, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 1, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 2, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 3, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 4, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 5, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 6, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 7, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 8, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 9, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 10, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 11, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 12, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 13, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 14, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 15, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 16, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 17, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 18, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 19, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 20, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 21, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 22, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 23, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 24, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 25, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 26, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 27, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 28, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 29, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 30, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 31, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 1, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 2, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 3, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 4, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 5, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 6, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 7, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 8, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 9, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 10, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 11, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 12, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 13, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 14, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 15, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 16, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 17, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 18, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 19, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 20, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 21, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 22, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 23, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 24, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 25, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 26, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 27, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 28, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 29, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 30, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 1, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 2, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 3, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 4, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 31, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 31, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 31, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 20, 0, 0),
# ...
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 31, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 31, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30}]}

# %% [markdown]
# <span style=color:blue>One way to fetch the data types of fields of documents in a collection.  (This works for db.listings_with_calendar because all documents in the collection have the same structure    </span>

# %%
# Retrieve a single document from the collection
doc = db.listings_with_calendar.find_one()

# Iterate over the keys of the retrieved document and retrieve the datatype of each value
for key in doc.keys():
    print(key, type(doc[key]))
for key in doc['dates_list'][0]:
    print(key, type(doc['dates_list'][0][key]))
# Out:
# _id <class 'str'>
# average_price <class 'float'>
# first_available_date <class 'datetime.datetime'>
# last_available_date <class 'datetime.datetime'>
# dates_list <class 'list'>
# date <class 'datetime.datetime'>
# available <class 'bool'>
# price <class 'float'>
# minimum_nights <class 'int'>
# maximum_nights <class 'int'>

# %% [markdown]
# <span style=color:blue>As you may recall from the notebook "Loading Local MongoDB with Listings & Reviews-v02e.ipynb", in general, you cannot fetch documents from MongoDB and write them into json files on your machine.  In the next 2 cells we work to create a function that transforms documents in db.listings_with_calendar into dicts that can be written out to json files.   </span>

# %%
doc = db.listings_with_calendar.find_one()
pprint.pp(doc)
# Out:
# {'_id': '10000070',
#  'average_price': 85.0,
#  'first_available_date': datetime.datetime(2024, 2, 6, 0, 0),
#  'last_available_date': datetime.datetime(2025, 2, 4, 0, 0),
#  'dates_list': [{'date': datetime.datetime(2024, 2, 6, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 7, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 8, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 9, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 10, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 11, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 12, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 13, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 14, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 15, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 16, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 17, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 18, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 19, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 20, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 21, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 22, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 23, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 24, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 25, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 26, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 27, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 28, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 2, 29, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 1, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 2, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 3, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 4, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 5, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 6, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 7, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 8, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 9, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 10, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 11, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 12, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 13, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 14, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 15, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 16, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 17, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 18, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 19, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 20, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 21, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 22, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 23, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 24, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 25, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 26, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 27, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 28, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 29, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 30, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 3, 31, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 1, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 2, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 3, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 4, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 5, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 6, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 7, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 8, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 9, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 10, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 11, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 12, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 13, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 14, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 15, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 16, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 17, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 18, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 19, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 20, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 21, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 22, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 23, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 24, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 25, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 26, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 27, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 28, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 29, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 4, 30, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 1, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 2, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 3, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 4, 0, 0),
#                  'available': True,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 5, 31, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 6, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 7, 31, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 8, 31, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 9, 20, 0, 0),
# ...
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 11, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2024, 12, 31, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 5, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 6, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 7, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 8, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 9, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 10, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 11, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 12, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 13, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 14, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 15, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 16, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 17, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 18, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 19, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 20, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 21, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 22, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 23, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 24, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 25, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 26, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 27, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 28, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 29, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 30, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 1, 31, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 1, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 2, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 3, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30},
#                 {'date': datetime.datetime(2025, 2, 4, 0, 0),
#                  'available': False,
#                  'price': 85.0,
#                  'minimum_nights': 30,
#                  'maximum_nights': 30}]}

# %%
def convert_lwc_to_json(doc):
    doc_new = {}
    for key in ['_id', 'average_price']:
        doc_new[key] = doc[key]
    for key in ['first_available_date', 'last_available_date']:
        doc_new[key] = doc[key].strftime('%Y-%m-%d')
    dlist = []
    for d in doc['dates_list']:
        d_new = {}
        d_new['date'] = d['date'].strftime('%Y-%m-%d')
        for key in ['price', 'minimum_nights', 'maximum_nights', 'available']:
            d_new[key] = d[key]
        dlist.append(d_new)
    doc_new['dates_list'] = dlist
    return doc_new

pprint.pp(convert_lwc_to_json(doc))
# Out:
# {'_id': '11194693',
#  'average_price': 57.0,
#  'first_available_date': '2024-02-06',
#  'last_available_date': '2025-02-04',
#  'dates_list': [{'date': '2024-02-06',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-07',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-08',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-09',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-10',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-11',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-12',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-13',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-14',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-15',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-16',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-17',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-18',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-19',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-20',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-21',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-22',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-23',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-24',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-25',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-26',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-27',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-28',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-02-29',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-01',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-02',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-03',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-04',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-05',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-06',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-07',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-08',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-09',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-10',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-11',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-12',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-13',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-14',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-15',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-16',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-17',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-18',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-19',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-20',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-21',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-22',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-23',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-24',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-25',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-26',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-27',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-28',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-29',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-30',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-03-31',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-01',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-02',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-03',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-04',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-05',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-06',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-07',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-08',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-09',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-10',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-11',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-12',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-13',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-14',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-15',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-16',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-17',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-18',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-19',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-20',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-21',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-22',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-23',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-24',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-25',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-26',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-27',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-28',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-29',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-04-30',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-01',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-02',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-03',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-04',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-05',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-06',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-07',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-08',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-09',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-10',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-11',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-12',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-13',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-14',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-15',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-16',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-17',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-18',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-19',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-20',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-21',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-22',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-23',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-24',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-25',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-26',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-27',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-28',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-29',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-30',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-05-31',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-01',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-02',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-03',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-04',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-05',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-06',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-07',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-08',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-09',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-10',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-11',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-12',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-13',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-14',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-15',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-16',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-17',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-18',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-19',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-20',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-21',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-22',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-23',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-24',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-25',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-26',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-27',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-28',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-29',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-06-30',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-01',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-02',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-03',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-04',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-05',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-06',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-07',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-08',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-09',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-10',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-11',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-12',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-13',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-14',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-15',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-16',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-17',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-18',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-19',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-20',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-21',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-22',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-23',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-24',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-25',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-26',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-27',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-28',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-29',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-30',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-07-31',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-01',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-02',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-03',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-04',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-05',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-06',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-07',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-08',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-09',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-10',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-11',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-12',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-13',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-14',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-15',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-16',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-17',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-18',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-19',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-20',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-21',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-22',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-23',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-24',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-25',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-26',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-27',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-28',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-29',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-30',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-08-31',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-01',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-02',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-03',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-04',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-05',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-06',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-07',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-08',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-09',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-10',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-11',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-12',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-13',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-14',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-15',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-16',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-17',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-18',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-19',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-20',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-21',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-22',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-23',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-24',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-25',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-26',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-27',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-28',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-29',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-09-30',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-10-01',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-10-02',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-10-03',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-10-04',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-10-05',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-10-06',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-10-07',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-10-08',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-10-09',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-10-10',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-10-11',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-10-12',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-10-13',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-10-14',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-10-15',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-10-16',
# ...
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-11-13',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-11-14',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-11-15',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-11-16',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-11-17',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-11-18',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-11-19',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-11-20',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-11-21',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-11-22',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-11-23',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-11-24',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-11-25',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-11-26',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-11-27',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-11-28',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-11-29',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-11-30',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-01',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-02',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-03',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-04',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-05',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-06',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-07',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-08',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-09',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-10',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-11',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-12',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-13',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-14',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-15',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-16',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-17',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-18',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-19',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-20',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-21',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-22',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-23',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-24',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-25',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-26',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-27',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-28',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-29',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-30',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2024-12-31',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-01',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-02',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-03',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-04',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-05',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-06',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-07',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-08',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-09',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-10',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-11',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-12',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-13',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-14',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-15',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-16',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-17',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-18',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-19',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-20',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-21',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-22',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-23',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-24',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-25',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-26',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-27',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-28',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-29',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-30',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-01-31',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-02-01',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-02-02',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-02-03',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False},
#                 {'date': '2025-02-04',
#                  'price': 57.0,
#                  'minimum_nights': 119,
#                  'maximum_nights': 120,
#                  'available': False}]}

# %% [markdown]
# <span style=color:blue>Will not fetch a small subset of db.listings_with_calendar, and write those documents into the json file "listings_with_calendar_subset.json".  This will be part of your submission for Programming Assignment 3.    </span>

# %%
print(db.listings_with_calendar.count_documents({}))

cursor = db.listings_with_calendar.find({'_id' : {'$regex' : '^111.*$'}})
    
l = list(cursor)
print(len(l))
# Out:
# 39201
# 43

# %%
cursor = db.listings_with_calendar.find({'_id' : {'$regex' : '^1000.*$'}})

output = []

for doc in cursor:
    output.append(convert_lwc_to_json(doc))

print(len(output))
# Out:
# 43

# %%
# Writing dict to a json file into a json file in a subdirectory
# Also putting this function into my util.py
def write_dict_to_dir_json(dict, dir, filename):
    with open(dir + '/' + filename, 'w') as fp:
        json.dump(dict, fp)

dir = 'OUTPUTS'
filename = 'listings_with_calendar_subset_1000.json'
write_dict_to_dir_json(output, dir, filename)

# %%
with open('OUTPUTS/listings_with_calendar_subset_1000.json', 'r') as file:
    data = json.load(file)

number_of_documents = len(data)
print(f"The file contains {number_of_documents} documents.")
# Out:
# The file contains 43 documents.
